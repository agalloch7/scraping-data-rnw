# %%
import pandas as pd
import langid
android = pd.read_csv("DiP/Philips/TextMining/App_Annie_Store_Stats_Reviews_Google Play_Philips Hue_2016_04_28-2017_03_22.csv", skiprows = 12, usecols=range(0,12))
android.head()
# Out:
#       Platform Language        Date                     App ID     App Name  \
# 0  Google Play  English  03/22/2017  com.philips.lighting.hue2  Philips Hue
# 1  Google Play  English  03/22/2017  com.philips.lighting.hue2  Philips Hue
# 2  Google Play  English  03/21/2017  com.philips.lighting.hue2  Philips Hue
# 3  Google Play  English  03/21/2017  com.philips.lighting.hue2  Philips Hue
# 4  Google Play  English  03/21/2017  com.philips.lighting.hue2  Philips Hue
#
#      Publisher ID       Publisher Name                User  Version  Rating  \
# 0  20200001517998  Philips Lighting BV           Alex Kim       NaN       2
# 1  20200001517998  Philips Lighting BV    Travis Meinders       NaN       1
# 2  20200001517998  Philips Lighting BV         brian cruz       NaN       2
# 3  20200001517998  Philips Lighting BV            Jacob Z       NaN       2
# 4  20200001517998  Philips Lighting BV          John King       NaN       5
#
# ...

# %%
for rev in android['Review']:
    android['lang'], android['prob'] = langid.classify(rev)

# %%
for i in range(android.shape[0]):
    store = langid.classify(android['Review'][i])

# %%
android['lang2'] = ''
android['prob2'] = ''

# %%
t1 = android [:50]

# %%
for index, row in t1.iterrows():
    t1['lang2'][index], t1['prob2'][index] = langid.classify(row['Review'])
# Out:
# /Users/yixuanli/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
t1.head()
# Out:
#       Platform Language        Date                     App ID     App Name  \
# 0  Google Play  English  03/22/2017  com.philips.lighting.hue2  Philips Hue
# 1  Google Play  English  03/22/2017  com.philips.lighting.hue2  Philips Hue
# 2  Google Play  English  03/21/2017  com.philips.lighting.hue2  Philips Hue
# 3  Google Play  English  03/21/2017  com.philips.lighting.hue2  Philips Hue
# 4  Google Play  English  03/21/2017  com.philips.lighting.hue2  Philips Hue
#
#      Publisher ID       Publisher Name                User  Version  Rating  \
# 0  20200001517998  Philips Lighting BV           Alex Kim       NaN       2
# 1  20200001517998  Philips Lighting BV    Travis Meinders       NaN       1
# 2  20200001517998  Philips Lighting BV         brian cruz       NaN       2
# 3  20200001517998  Philips Lighting BV            Jacob Z       NaN       2
# 4  20200001517998  Philips Lighting BV          John King       NaN       5
#
# ...

# %%
t2 = t1[t1.lang2 == 'en']

# %%
t2
# Out:
#        Platform Language        Date                     App ID     App Name  \
# 0   Google Play  English  03/22/2017  com.philips.lighting.hue2  Philips Hue
# 1   Google Play  English  03/22/2017  com.philips.lighting.hue2  Philips Hue
# 2   Google Play  English  03/21/2017  com.philips.lighting.hue2  Philips Hue
# 3   Google Play  English  03/21/2017  com.philips.lighting.hue2  Philips Hue
# 4   Google Play  English  03/21/2017  com.philips.lighting.hue2  Philips Hue
# 5   Google Play  English  03/20/2017  com.philips.lighting.hue2  Philips Hue
# 6   Google Play  English  03/20/2017  com.philips.lighting.hue2  Philips Hue
# 7   Google Play  English  03/20/2017  com.philips.lighting.hue2  Philips Hue
# 8   Google Play  English  03/20/2017  com.philips.lighting.hue2  Philips Hue
# 9   Google Play  English  03/20/2017  com.philips.lighting.hue2  Philips Hue
# 10  Google Play  English  03/19/2017  com.philips.lighting.hue2  Philips Hue
# ...

# %%
android['langt'].unique()
# Out:
# array(['en', 'it', 'ro', 'nl', 'de', 'fr', 'sv', 'sk', 'es', 'da', 'nb',
#        'ca', 'pt', 'eu', 'pl', 'et', 'bg', 'no', 'sl', 'fi', 'mt', 'hr',
#        'zh', 'cs', 'mk', 'el', 'lb', 'ko', 'hu', 'ms', 'af', 'tr', 'ru',
#        'he', 'gl'], dtype=object)

# %%
t1 = android[:500]

# %%
for index, row in android.iterrows():
    android['langt'][index] = langid.classify(row['Review'])
# Out:
# /Users/yixuanli/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
android['prob2'].unique()
# Out:
# array([-724.12296057])

# %%
langid.classify(android['Review'][24])
# Out:
# ('ro', -63.61913013458252)

# %%
android['Review'][24]
# Out:
# ' Nu func\xc8\x9bioneaz\xc4\x83 wake-up \xc8\x99i sleep. '

# %%
android.head()
# Out:
#       Platform  Language        Date                     App ID     App Name  \
# 0  Google Play   English  03/22/2017  com.philips.lighting.hue2  Philips Hue
# 1          NaN   Swedish  03/21/2017                        NaN          NaN
# 2          NaN   Chinese  03/20/2017                        NaN          NaN
# 3          NaN  Romanian  03/19/2017                        NaN          NaN
# 4          NaN   Italian  03/18/2017                        NaN          NaN
#
#    Publisher ID       Publisher Name                User  Version  Rating  \
# 0  2.020000e+13  Philips Lighting BV           Alex Kim       NaN     2.0
# 1           NaN                  NaN    Travis Meinders       NaN     1.0
# 2           NaN                  NaN         brian cruz       NaN     5.0
# 3           NaN                  NaN            Jacob Z       NaN     3.0
# 4           NaN                  NaN          John King       NaN     4.0
#
# ...

# %%
android.lang2.unique()
# Out:
# array([u'en'], dtype=object)

# %%
detect(android['Review'][0])
# Out:
# u'en'

# %%
t = android[android.lang2 == 'en']
t.shape
# Out:
# (3306, 14)

# %%
df = proccessed[proccessed.lang2 == 'en']

# %%
df.tail()
# Out:
#       business_id  business_overall_stars business_name  user_name version  \
# 4665          NaN                     1.8   Philips Hue      thx67       2
# 4666          NaN                     1.8   Philips Hue   funki_al       2
# 4667          NaN                     1.8   Philips Hue     leenig       2
# 4668          NaN                     1.8   Philips Hue  Stuart DJ       2
# 4669          NaN                     1.8   Philips Hue   DaveyRdg       2
#
#       review_stars                                               text lang  \
# 4665             1  They consistently managed 1 star reviews for t...   en
# 4666             1  Appalling. I can't import scenes or select spe...   en
# 4667             5  A lovely update for a wonderful product - can ...   en
# 4668             1  No Apple Watch support. I'm sticking with the ...   en
# 4669             5  This is a really great update to the Philips H...   en
#
#      lang2
# 4665    en
# 4666    en
# 4667    en
# 4668    en
# ...

# %%
df.shape
# Out:
# (4670, 9)

# %%
proccessed.shape
# Out:
# (4670, 8)

# %%
proccessed.lang2.unique()
# Out:
# array([u'en'], dtype=object)

# %%
import pandas as pd
fbid = "lovemattersafrica"
df_status = pd.read_csv("%s_facebook_statuses.csv" %fbid)

# %%
df_comments = pd.read_csv("%s_facebook_comments.csv" %fbid)

# %%
df_comments.parent_id.count()
# Out:
# 27703

# %%
df_status['engagement'] = df_status['num_reactions'] + df_status['num_comments'] + df_status['num_shares']

# %%
df_status.engagement.max()
# Out:
# 443150

# %%
i = pd.Index(df_status["engagement"]).get_loc(df_status.engagement.max())

# %%
i
# Out:
# 3505

# %%
df_status["status_message"][i]
# Out:
# "Do you agree  #teamlovematters....it's goodnight."

# %%
df_status.head()
# Out:
#                           status_id  \
# 0  387386548007364_1390373157708693
# 1  387386548007364_1390001797745829
# 2  387386548007364_1390002394412436
# 3  387386548007364_1389134784499197
# 4  387386548007364_1389489631130379
#
#                                       status_message  \
# 0  Get more information and tips on #menstruating...
# 1  My #girlfriend has her #period for two days on...
# 2  Do you agree #TeamLoveMatters? Have a great Mo...
# 3                Have a good night #TeamLoveMatters.
# 4  Here's some #tips on  #foreplay, everything th...
#
#                        link_name status_type  \
# 0                Timeline Photos       photo
# 1  How long should periods last?        link
# 2                Timeline Photos       photo
# 3                Timeline Photos       photo
# 4  Foreplay: turning up the heat        link
#
#                                          status_link  \
# 0  https://www.facebook.com/LoveMattersAfrica/pho...
# ...

# %%
i = pd.Index(df_status["engagement"]).get_loc(df_status.engagement.max())
message = df_status["status_message"][i]

# %%
df_status["permalink_url"][i]
# Out:
# 'https://www.facebook.com/LoveMattersAfrica/posts/875130119233002:0'

# %%
if df_comments['status_message']:
    pass
else:
    print df_status['status_message'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-905b54925e96> in <module>()
# ----> 1 if df_comments['status_message']:
#       2     pass
#       3 else:
#       4     print df_status['status_message'][0]
#
# /Users/yixuanli/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /Users/yixuanli/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
from nltk import pos_tag, word_tokenize
text = df_comments['comment_message']
df_comments['com_len'] = [len(word_tokenize(str(sent).decode('utf-8'))) for sent in text]

# %%
df_comments.head()
# Out:
#                           comment_id                         status_id  \
# 0  1390373157708693_1390742507671758  387386548007364_1390373157708693
# 1  1390001797745829_1390247247721284  387386548007364_1390001797745829
# 2  1390001797745829_1390247907721218  387386548007364_1390001797745829
# 3  1390001797745829_1390251587720850  387386548007364_1390001797745829
# 4  1390001797745829_1391355817610427  387386548007364_1390001797745829
#
#                            parent_id  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4  1390001797745829_1390251587720850
#
#                                      comment_message   comment_author  \
# 0                                        [[STICKER]]   Sikyo Beatrice
# 1  two days? datz nt normal atlist 3days consult ...  Atim Naome Akol
# 2                                            3-4days  Atim Naome Akol
# ...

# %%
superusers = df_comments['comment_author'].value_counts()

# %%
if 
superusers[:3]
# Out:
# Love Matters Africa    994
# Jaqie Wa Kinyua        396
# Salome Lunyolo         390
# Name: comment_author, dtype: int64

# %%
s = superusers[:5]

# %%
s.
# Out:
# 'comment_author'

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s1 = str(s).split(" ")

# %%
s1
# Out:
# ['Love',
#  'Matters',
#  'Africa',
#  '',
#  '',
#  '',
#  '994\nJaqie',
#  'Wa',
#  'Kinyua',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '396\nSalome',
#  'Lunyolo',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '390\nPrince',
#  'Rene',
#  'Charles',
#  '',
#  '',
#  '',
#  '326\nPattz',
#  'Wain',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '307\nName:',
#  'comment_author,',
#  'dtype:',
#  'int64']

# %%
from nltk.probability import FreqDist
fdist1 = FreqDist(df_comments['comment_message'])
l = fdist1.most_common(10)

# %%
l
# Out:
# [('[[STICKER]]', 1443),
#  ('True', 1071),
#  ('Very true', 333),
#  ('Yes', 310),
#  ('[[PHOTO]]', 285),
#  ('Amen', 258),
#  ('true', 239),
#  ('No', 214),
#  ('Exactly', 201),
#  ('Sure', 142)]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
import string
import gensim
from gensim import corpora
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()

def clean(doc):
    stop_free = " ".join([i for i in str(doc).lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.decode('utf-8').split())
    return normalized

reviews_clean = [clean(reviews).split() for reviews in df_status['status_message'][:100]]
# Creating the term dictionary of our courpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(reviews_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(review) for review in reviews_clean]

# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=5, id2word = dictionary, passes=50)

# %%
comments_topics = ldamodel.print_topics(num_topics=5, num_words=5)

# %%
comments_topics
# Out:
# [(0,
#   u'0.024*"tip" + 0.024*"clean" + 0.024*"nice" + 0.019*"here" + 0.016*"morning"'),
#  (1,
#   u'0.043*"get" + 0.037*"information" + 0.037*"httpslovematterscoke" + 0.026*"tip" + 0.017*"kissing"'),
#  (2,
#   u'0.024*"get" + 0.019*"know" + 0.015*"right" + 0.015*"kenyabuzz" + 0.015*"market"'),
#  (3,
#   u'0.021*"teamlovematters" + 0.016*"morning" + 0.015*"it" + 0.015*"relationship" + 0.015*"youre"'),
#  (4,
#   u'0.077*"teamlovematters" + 0.062*"good" + 0.047*"night" + 0.021*"know" + 0.021*"enjoy"')]

# %%
[i[1] for i in comments_topics]
# Out:
# [u'0.024*"tip" + 0.024*"clean" + 0.024*"nice" + 0.019*"here" + 0.016*"morning"',
#  u'0.043*"get" + 0.037*"information" + 0.037*"httpslovematterscoke" + 0.026*"tip" + 0.017*"kissing"',
#  u'0.024*"get" + 0.019*"know" + 0.015*"right" + 0.015*"kenyabuzz" + 0.015*"market"',
#  u'0.021*"teamlovematters" + 0.016*"morning" + 0.015*"it" + 0.015*"relationship" + 0.015*"youre"',
#  u'0.077*"teamlovematters" + 0.062*"good" + 0.047*"night" + 0.021*"know" + 0.021*"enjoy"']

# %%
type(l)
# Out:
# list

# %%
for a, b in l:
    print '{:<7s} {}'.format(a, b)
# Out:
# [[STICKER]] 1443
# True    1071
# Very true 333
# Yes     310
# [[PHOTO]] 285
# Amen    258
# true    239
# No      214
# Exactly 201
# Sure    142

# %%
from math import floor
def floored_percentage(val, digits):
    val *= 10 ** (digits + 2)
    return '{1:.{0}f}%'.format(digits, floor(val) / 10 ** digits)

# %%
frac_pos = 5/7

# %%
floored_percentage(5/10, 2)
# Out:
# '0.00%'

# %%
"{:.1%}".format(5/7)
# Out:
# '0.0%'

# %%
type(superusers)
# Out:
# pandas.core.series.Series

# %%
df_comments.mode()
# Out:
#                           comment_id                         status_id  \
# 0   563515040394513_1033270206752325  387386548007364_1059550750790937
# 1   563515040394513_1033270360085643                               NaN
# 2   563515040394513_1033300040082675                               NaN
# 3   563515040394513_1033304370082242                               NaN
# 4   563515040394513_1033406663405346                               NaN
# 5   563515040394513_1033422510070428                               NaN
# 6   563515040394513_1033431756736170                               NaN
# 7   563515040394513_1033454050067274                               NaN
# 8   563515040394513_1033456146733731                               NaN
# 9   563515040394513_1033507276728618                               NaN
# 10  563515040394513_1033511070061572                               NaN
# 11  563515040394513_1033527986726547                               NaN
# ...
